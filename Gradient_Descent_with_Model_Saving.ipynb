# %% [markdown]
# <a href="https://colab.research.google.com/github/rkp74/Gradient_Descent/blob/main/Gradient_Descent_with_Model_Saving.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gradient Descent Code

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.array([1,2,3,4,5])
y1 = np.array([5,7,9,11,13])

# %%
x1
# Out:
# array([1, 2, 3, 4, 5])

# %%
def gradient_descent(x,y):
  m_curr = 0
  b_curr = 0
  n = len(x)
  lr = 0.06
  iterations = 10000

  for i in range(iterations):
    y_predicted = m_curr * x + b_curr
    cost = 1/n *sum([val**2 for val in (y-y_predicted)] )
    md = -2/n *sum(x*(y-y_predicted))
    bd = -2/n *sum(y-y_predicted)
    m_curr = m_curr - lr*md
    b_curr = b_curr - lr*bd
    print("m {} , b {} , cost {} , iteration {}".format(m_curr , b_curr , cost , i))

# %%
gradient_descent(x1,y1)
# Out:
# Streaming output truncated to the last 5000 lines.
# m 2.0000000000000036 , b 2.999999999999987 , cost 2.8398992587956425e-29 , iteration 5000
# m 2.0000000000000036 , b 2.999999999999987 , cost 2.8398992587956425e-29 , iteration 5001
# m 2.0000000000000036 , b 2.999999999999987 , cost 2.8398992587956425e-29 , iteration 5002
# m 2.0000000000000036 , b 2.999999999999987 , cost 2.8398992587956425e-29 , iteration 5003
# m 2.0000000000000036 , b 2.999999999999987 , cost 2.8398992587956425e-29 , iteration 5004
# m 2.0000000000000036 , b 2.999999999999987 , cost 2.8398992587956425e-29 , iteration 5005
# m 2.0000000000000036 , b 2.999999999999987 , cost 2.8398992587956425e-29 , iteration 5006
# m 2.0000000000000036 , b 2.999999999999987 , cost 2.8398992587956425e-29 , iteration 5007
# m 2.0000000000000036 , b 2.999999999999987 , cost 2.8398992587956425e-29 , iteration 5008
# m 2.0000000000000036 , b 2.999999999999987 , cost 2.8398992587956425e-29 , iteration 5009
# ...

# %% [markdown]
# # Exercise

# %% [markdown]
# ## Gradient Descent

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
x = np.array(df.math)

# %%
y = np.array(df.cs)

# %%
x
# Out:
# array([92, 56, 88, 70, 80, 49, 65, 35, 66, 67])

# %%
y
# Out:
# array([98, 68, 81, 80, 83, 52, 66, 30, 68, 73])

# %%
import math

# %%
def gradient_descent2(x,y):
  m_curr = b_curr = 0
  n = len(x)
  iterations = 100000
  lr = 0.000001
  cost_prev = 0
  for i in range(iterations):
    y_predicted = m_curr * x + b_curr
    cost = 1/n*sum([val**2 for val in (y-y_predicted)])
    md = -2/n*sum(x*(y-y_predicted))
    bd = -2/n*sum(y-y_predicted)
    m_curr = m_curr - lr * md
    b_curr = b_curr - lr * bd

    if math.isclose(cost , cost_prev,rel_tol = 1e-09 , abs_tol = 0.0):
      break
    cost_prev = cost
    print("m {} , b{} , cost {} , iteration {}".format(m_curr , b_curr , cost , i))

# %%
gradient_descent2(x,y)
# Out:
# Streaming output truncated to the last 5000 lines.
# m 1.0442627839177925 , b0.03535184749856808 , cost 31.80737853750213 , iteration 95000
# m 1.044262780872833 , b0.03535206328694167 , cost 31.80737849092823 , iteration 95001
# m 1.044262777827874 , b0.03535227907529048 , cost 31.8073784443543 , iteration 95002
# m 1.0442627747829152 , b0.035352494863614525 , cost 31.807378397780397 , iteration 95003
# m 1.0442627717379567 , b0.0353527106519138 , cost 31.807378351206548 , iteration 95004
# m 1.0442627686929986 , b0.03535292644018831 , cost 31.80737830463272 , iteration 95005
# m 1.044262765648041 , b0.03535314222843804 , cost 31.807378258058886 , iteration 95006
# m 1.0442627626030836 , b0.035353358016663006 , cost 31.807378211485016 , iteration 95007
# m 1.0442627595581266 , b0.0353535738048632 , cost 31.807378164911217 , iteration 95008
# m 1.04426275651317 , b0.03535378959303863 , cost 31.807378118337358 , iteration 95009
# ...

# %%
cs = 1.0444001646699994 * int(input()) + 0.02561603019258942
print(cs)
# Out:
# 56
# 58.51202525171255

# %% [markdown]
# ## Linear Regression

# %%
df =pd.read_csv("/content/test_scores.csv")

# %%
from sklearn import linear_model

# %%
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["math"] , df["cs"])

# %%
model = linear_model.LinearRegression()

# %%
model.fit(df[["math"]],df[["cs"]])
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[1.01773624]])

# %%
model.intercept_
# Out:
# array([1.91521931])

# %% [markdown]
# Generally This doesnt happpen when we apply linear regression as here data is so random thats why results are varying so much in case of b.

# %% [markdown]
# ## Save Model using Pickle

# %%
import pickle

# %%
with open('modelPickle' , 'wb') as f:
  pickle.dump(model,f)

# %%
with open('modelPickle', 'rb') as f:
  mp = pickle.load(f)

# %%
mp.predict([[45]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[47.71335001]])

# %% [markdown]
# ## Save Model using Joblib

# %%
import joblib

# %%
joblib.dump(model , 'model_joblib')
# Out:
# ['model_joblib']

# %%
mj = joblib.load('model_joblib')

# %%
mj.predict([[45]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[47.71335001]])
